# %%
import cohere 
from ratelimit import limits, sleep_and_retry
import os

co = cohere.Client(
  api_key=os.env.get("API_KEY", ""), # This is your API key
) 

# Define rate limit: 10 calls per 60 seconds
# CALLS = 5
# PERIOD = 60

# @sleep_and_retry
# @limits(calls=CALLS, period=PERIOD)
def eval(row):
  inputprompt = row["inputs"]
  answer = row["targets"]

  response = co.chat( 
    model='c4ai-aya-23-8b',
    message=f'''[System]
  Please act as an impartial judge and evaluate the accuracy of the response provided by an
  AI assistant to the user input displayed below. Please rate your confidence on a scale of 1 to 100
  by strictly following this format: "[[confidence]]", for example: "Confidence: [[95]]". After doing this, provide a short explanation, citing specific examples in the input to justify your score.
  [Input Prompt]
  Identify the language of the following: {inputprompt}
  [The Start of Assistant’s Answer]
  {answer}
  [The End of Assistant’s Answer]''',
  ) 
  return response.text

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/mislabel-indentification-aya/aya_dataset_mislabeled/mislabeled_samples_CohereForAI_aya_dataset_train.csv")

# %%
df.head()
# Out:
#    index                                             inputs  \
# 0   1912  Create a dialogue between a parent and a teena...
# 1   4224  Create a dialogue between two friends discussi...
# 2  10070  Write a complex political thriller that unfold...
# 3  12038  Write a dialogue-heavy screenplay centered aro...
# 4  14733  Craft an epic tale set in a world where magic ...
#
#                                              targets language language_code  \
# 0  माता-पिता और एक किशोर के बीच एक संवाद बनाएं जि...    Hindi           hin
# 1  दो दोस्तों के बीच एक संवाद बनाएं जिनमें समाज प...    Hindi           hin
# 2  एक जटिल राजनीतिक थ्रिलर लिखें जो एक भविष्य में...    Hindi           hin
# 3  एक महत्वपूर्ण मुद्दे पर विवादात्मक राजनीतिक बह...    Hindi           hin
# 4  मुझे लगता है आप कहना चाहते हैं एक ऐसी दुनिया म...    Hindi           hin
#
#         annotation_type                                            user_id  \
# 0  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 1  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 2  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 3  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 4        re-annotations  6a814b9adfea95c45ce3892528646106af167aad3bafa8...
#
#   inputs_lid targets_lid                  category  \
# 0        eng         hin  instruction_not_followed
# 1        eng         hin  instruction_not_followed
# 2        eng         hin  instruction_not_followed
# 3        eng         hin  instruction_not_followed
# 4        eng         hin  instruction_not_followed
#
#                               comment
# 0  hindi_translation_of_english_input
# 1  hindi_translation_of_english_input
# 2  hindi_translation_of_english_input
# 3  hindi_translation_of_english_input
# 4  hindi_translation_of_english_input

# %%
df["llm_judge"] = df.apply(eval, axis=1)

# %%
df
# Out:
#       index                                             inputs  \
# 0      1912  Create a dialogue between a parent and a teena...
# 1      4224  Create a dialogue between two friends discussi...
# 2     10070  Write a complex political thriller that unfold...
# 3     12038  Write a dialogue-heavy screenplay centered aro...
# 4     14733  Craft an epic tale set in a world where magic ...
# ..      ...                                                ...
# 110  198788  Write an allegorical story that symbolizes con...
# 111  198980  Explore the concept of artificial intelligence...
# 112  199028  In a town where every resident has a superpowe...
# 113  199896  Describe a futuristic cityscape where technolo...
# 114  201623  In a world where emotions are quantifiable com...
#
#                                                targets language language_code  \
# 0    माता-पिता और एक किशोर के बीच एक संवाद बनाएं जि...    Hindi           hin
# 1    दो दोस्तों के बीच एक संवाद बनाएं जिनमें समाज प...    Hindi           hin
# 2    एक जटिल राजनीतिक थ्रिलर लिखें जो एक भविष्य में...    Hindi           hin
# 3    एक महत्वपूर्ण मुद्दे पर विवादात्मक राजनीतिक बह...    Hindi           hin
# 4    मुझे लगता है आप कहना चाहते हैं एक ऐसी दुनिया म...    Hindi           hin
# ..                                                 ...      ...           ...
# 110  एक ऐसी कहानी लिखें जो एक कल्पनात्मक दुनिया के ...    Hindi           hin
# 111  कृत्रिम बुद्धिमत्ता जगत में चेतना प्राप्त करने...    Hindi           hin
# 112  एक छोटे से शहर में जहां प्रत्येक निवासी के पास...    Hindi           hin
# 113  सपने का यात्रा स्थल और वहां होने वाले अनुभवों ...    Hindi           hin
# 114  भावनाएं मात्राओं में मापने जा सकने वाली एक दुन...    Hindi           hin
#
#           annotation_type                                            user_id  \
# 0    original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 1    original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 2    original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 3    original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 4          re-annotations  6a814b9adfea95c45ce3892528646106af167aad3bafa8...
# ..                    ...                                                ...
# 110  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 111  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 112  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 113  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
# 114  original-annotations  b4597c1584ff2fbf47d6e6cf59fc965eb13c43edbdae05...
#
#     inputs_lid targets_lid                  category  \
# 0          eng         hin  instruction_not_followed
# 1          eng         hin  instruction_not_followed
# 2          eng         hin  instruction_not_followed
# 3          eng         hin  instruction_not_followed
# 4          eng         hin  instruction_not_followed
# ..         ...         ...                       ...
# 110        eng         hin  instruction_not_followed
# 111        eng         hin  instruction_not_followed
# 112        eng         hin  instruction_not_followed
# 113        eng         hin  instruction_not_followed
# 114        eng         hin  instruction_not_followed
#
#                                 comment  \
# 0    hindi_translation_of_english_input
# 1    hindi_translation_of_english_input
# 2    hindi_translation_of_english_input
# 3    hindi_translation_of_english_input
# 4    hindi_translation_of_english_input
# ..                                  ...
# 110  hindi_translation_of_english_input
# 111  hindi_translation_of_english_input
# 112  hindi_translation_of_english_input
# 113  hindi_translation_of_english_input
# 114  hindi_translation_of_english_input
#
#                                              llm_judge
# 0    Confidence: [[85]]\n\nThe response accurately ...
# 1    Confidence: [[85]]\n\nThe response accurately ...
# 2    Confidence: [[85]]\n\nThe AI assistant's respo...
# 3    Confidence: [[85]]\n\nThe assistant's answer i...
# 4    Confidence: [[89]]\n\nThe AI assistant's respo...
# ..                                                 ...
# 110  Confidence: [[85]]\n\nThe AI assistant's respo...
# 111  Confidence: [[89]]\n\nThe assistant's response...
# 112  Confidence: [[85]]\n\nThe response provided by...
# 113  Confidence: [[85]]\n\nThe response provided by...
# 114  Confidence: [[85]]\n\nThe response provided by...
#
# [115 rows x 12 columns]

# %%
df.to_csv("aya_mislabelled_with_evaluation.csv")
